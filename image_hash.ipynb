# %%
from PIL import Image

import imagehash

def img(img_path):
    """
    图片哈希（类似：4f999cc90979704c）
    :param img_path: 图片路径
    :return: <class 'imagehash.ImageHash'>
    """
    img1 = Image.open(img_path)
    res = imagehash.dhash(img1)
    return res


def hamm_img(res1, res2):
    """
    汉明距离，汉明距离越小说明越相似，等 0 说明是同一张图片，大于10越上，说明完全不相似
    :param res1:
    :param res2:
    :return:
    """
    str1 = str(res1)  # <class 'imagehash.ImageHash'> 转成 str
    str2 = str(res2)
    num = 0  # 用来计算汉明距离
    for i in range(len(str1)):
        if str1[i] != str2[i]:
            num += 1
    return num


if __name__ == '__main__':
    img_path1 = 'D:/image/16.jpg'
    img_path2 = 'D:/image/b47.png'
    res = hamm_img(img(img_path1),img(img_path2))
    print('汉明距离是:', res)
# Out:
# 汉明距离是: 16

# %%
import cv2
import numpy as np
from PIL import Image
import requests
from io import BytesIO
# import matplotlib
# matplotlib.use('TkAgg')
# import matplotlib.pyplot as plt

def pHash(img):
    # 感知哈希算法
    # 缩放32*32
    img = cv2.resize(img, (32, 32))   # , interpolation=cv2.INTER_CUBIC
 
    # 转换为灰度图
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # 将灰度图转为浮点型，再进行dct变换
    dct = cv2.dct(np.float32(gray))
    # opencv实现的掩码操作
    dct_roi = dct[0:8, 0:8]
 
    hash = []
    avreage = np.mean(dct_roi)
    for i in range(dct_roi.shape[0]):
        for j in range(dct_roi.shape[1]):
            if dct_roi[i, j] > avreage:
                hash.append(1)
            else:
                hash.append(0)
    return hash

def cmpHash(hash1, hash2):
    # Hash值对比
    # 算法中1和0顺序组合起来的即是图片的指纹hash。顺序不固定，但是比较的时候必须是相同的顺序。
    # 对比两幅图的指纹，计算汉明距离，即两个64位的hash值有多少是不一样的，不同的位数越小，图片越相似
    # 汉明距离：一组二进制数据变成另一组数据所需要的步骤，可以衡量两图的差异，汉明距离越小，则相似度越高。汉明距离为0，即两张图片完全一样
    n = 0
    # hash长度不同则返回-1代表传参出错
    if len(hash1) != len(hash2):
        return -1
    # 遍历判断
    for i in range(len(hash1)):
        # 不相等则n计数+1，n最终为相似度
        if hash1[i] != hash2[i]:
            n = n + 1
    return n
 
def getImageByUrl(url):
    # 根据图片url 获取图片对象
    html = requests.get(url, verify=False)
    image = Image.open(BytesIO(html.content))
    return image


# def PILImageToCV():
#     # PIL Image转换成OpenCV格式
#     path = "D:/image/b47.png"
#     img = Image.open(path)
# #     plt.subplot(121)
# #     plt.imshow(img)
#     print(isinstance(img, np.ndarray))
#     img = cv2.cvtColor(np.asarray(img), cv2.COLOR_RGB2BGR)
#     print(isinstance(img, np.ndarray))
# #     plt.subplot(122)
# #     plt.imshow(img)
# #     plt.show()
 
# def CVImageToPIL():
#     # OpenCV图片转换为PIL image
#     path = "D:/image/b47.png"
#     img = cv2.imread(path)
#     # cv2.imshow("OpenCV",img)
# #     plt.subplot(121)
# #     plt.imshow(img)
 
#     img2 = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# #     plt.subplot(122)
# #     plt.imshow(img2)
# #     plt.show()


# def bytes_to_cvimage(filebytes):
#     # 图片字节流转换为cv image
#     image = Image.open(filebytes)
#     img = cv2.cvtColor(np.asarray(image), cv2.COLOR_RGB2BGR)
#     return img

def runAllImageSimilaryFun(para1, para2):
    # 均值、差值、感知哈希算法三种算法值越小，则越相似,相同图片值为0
    # 三直方图算法和单通道的直方图 0-1之间，值越大，越相似。 相同图片为1
 
    # t1,t2   14;19;10;  0.70;0.75
    # t1,t3   39 33 18   0.58 0.49
    # s1,s2  7 23 11     0.83 0.86  挺相似的图片
    # c1,c2  11 29 17    0.30 0.31
 
    if para1.startswith("http"):
         # 根据链接下载图片，并转换为opencv格式
        img1 = getImageByUrl(para1)
        img1 = cv2.cvtColor(np.asarray(img1), cv2.COLOR_RGB2BGR)
 
        img2 = getImageByUrl(para2)
        img2 = cv2.cvtColor(np.asarray(img2), cv2.COLOR_RGB2BGR)
    else:
        # 通过imread方法直接读取物理路径
        img1 = cv2.imread(para1)
        img2 = cv2.imread(para2)
 
 
    hash1 = pHash(img1)
    hash2 = pHash(img2)
    n3 = cmpHash(hash1, hash2)
    print('感知哈希算法相似度pHash：', n3)

# %%
def runAllImageSimilaryFun(para1, para2):
    # 均值、差值、感知哈希算法三种算法值越小，则越相似,相同图片值为0
    # 三直方图算法和单通道的直方图 0-1之间，值越大，越相似。 相同图片为1
 
    # t1,t2   14;19;10;  0.70;0.75
    # t1,t3   39 33 18   0.58 0.49
    # s1,s2  7 23 11     0.83 0.86  挺相似的图片
    # c1,c2  11 29 17    0.30 0.31
 
    if para1.startswith("http"):
         # 根据链接下载图片，并转换为opencv格式
        img1 = getImageByUrl(para1)
        img1 = cv2.cvtColor(np.asarray(img1), cv2.COLOR_RGB2BGR)
 
        img2 = getImageByUrl(para2)
        img2 = cv2.cvtColor(np.asarray(img2), cv2.COLOR_RGB2BGR)
    else:
        # 通过imread方法直接读取物理路径
        img1 = cv2.imread(para1)
        img2 = cv2.imread(para2)
 
 
    hash1 = pHash(img1)
    hash2 = pHash(img2)
    n3 = cmpHash(hash1, hash2)
    print('感知哈希算法相似度pHash：', n3)


if __name__ == "__main__":
    p1="D:/image/hg. (1).jpg"
    p2="D:/image/hg. (41).jpg"
    runAllImageSimilaryFun(p1,p2)
# Out:
# 感知哈希算法相似度pHash： 14

# %%
import os 
if __name__ == "__main__": 
def file_name(file_dir):  
    L=[]  
    for root, dirs, files in os.walk(file_dir): 
    for file in files: 
        if os.path.splitext(file)[1] == '.jpeg': 
        L.append(os.path.join(root, file)) 
    return L
# Out:
# img0 = getImageByUrl(para0)
# img1 = getImageByUrl(para1)
# img2 = getImageByUrl(para2)
# img3 = getImageByUrl(para3)
# img4 = getImageByUrl(para4)

# %%
import os 
if __name__ == "__main__": 
    def file_name(file_dir):  
        L=[]  
        for root, dirs, files in os.walk(file_dir): 
            for file in files: 
                if os.path.splitext(file)[1] == '.jpg' or 'png': 
                    L.append(os.path.join(root, file))
        return L
file_name("D:/image")
# Out:
# ['D:/image\\16.jpg',
#  'D:/image\\5b1a4df184176adba0438e165398be7.png',
#  'D:/image\\7d5f69b950ab832c639f03baa659de7.png',
#  'D:/image\\b47.png',
#  'D:/image\\hg. (41).jpg',
#  'D:/image\\不合格图片.zip',
#  'D:/image\\不合格问题图片.zip',
#  'D:/image\\合格图片.zip',
#  'D:/image\\问题图片收集.rar',
#  'D:/image\\dataset\\image.py',
#  'D:/image\\dataset\\image_best_model.hdf5',
#  'D:/image\\dataset\\image_ide.py',
#  'D:/image\\dataset\\image_test1.zip',
#  'D:/image\\dataset\\image_train.zip',
#  'D:/image\\dataset\\hg1\\hg.23.jpg',
#  'D:/image\\dataset\\hg1\\hg.24.jpg',
#  'D:/image\\dataset\\hg1\\hg.25.jpg',
#  'D:/image\\dataset\\hg1\\hg.26.jpg',
#  'D:/image\\dataset\\hg1\\hg.27.jpg',
#  'D:/image\\dataset\\hg1\\hg.28.jpg',
#  'D:/image\\dataset\\hg1\\hg.29.jpg',
#  'D:/image\\dataset\\hg1\\hg.30.jpg',
#  'D:/image\\dataset\\hg1\\hg.31.jpg',
#  'D:/image\\dataset\\hg1\\hg.32.jpg',
#  'D:/image\\dataset\\hg1\\hg.33.jpg',
#  'D:/image\\dataset\\hg1\\hg.34.jpg',
#  'D:/image\\dataset\\hg1\\hg.35.jpg',
#  'D:/image\\dataset\\hg1\\hg.36.jpg',
#  'D:/image\\dataset\\hg1\\hg.37.jpg',
#  'D:/image\\dataset\\hg1\\hg.38.jpg',
#  'D:/image\\dataset\\hg1\\hg.39.jpg',
#  'D:/image\\dataset\\hg1\\hg.40.jpg',
#  'D:/image\\dataset\\hg1\\hg.41.jpg',
#  'D:/image\\dataset\\hg1\\hg.42.jpg',
#  'D:/image\\dataset\\hg1\\hg.43.jpg',
#  'D:/image\\dataset\\hg1\\hg.44.jpg',
#  'D:/image\\dataset\\hg1\\hg.45.jpg',
#  'D:/image\\dataset\\hg1\\hg.46.jpg',
#  'D:/image\\dataset\\hg1\\hg.47.jpg',
#  'D:/image\\dataset\\hg1\\hg.48.jpg',
#  'D:/image\\dataset\\hg1\\hg.49.jpg',
#  'D:/image\\dataset\\hg1\\hg.50.jpg',
#  'D:/image\\dataset\\hg1\\hg.51.jpg',
#  'D:/image\\dataset\\hg1\\hg.52.jpg',
#  'D:/image\\dataset\\hg1\\hg.53.jpg',
#  'D:/image\\dataset\\hg1\\hg.54.jpg',
#  'D:/image\\dataset\\hg1\\hg.55.jpg',
#  'D:/image\\dataset\\hg1\\hg.56.jpg',
#  'D:/image\\dataset\\hg1\\hg.57.jpg',
#  'D:/image\\dataset\\hg1\\hg.58.jpg',
#  'D:/image\\dataset\\hg1\\hg.59.jpg',
#  'D:/image\\dataset\\hg1\\hg.60.jpg',
#  'D:/image\\dataset\\hg1\\hg.61.jpg',
#  'D:/image\\dataset\\hg1\\hg.62.jpg',
#  'D:/image\\dataset\\hg1\\hg.63.jpg',
#  'D:/image\\dataset\\hg1\\hg.64.jpg',
#  'D:/image\\dataset\\hg1\\hg.65.jpg',
#  'D:/image\\dataset\\hg1\\hg.66.jpg',
#  'D:/image\\dataset\\hg1\\hg.67.jpg',
#  'D:/image\\dataset\\hg1\\hg.68.jpg',
#  'D:/image\\dataset\\hg1\\hg.69.jpg',
#  'D:/image\\dataset\\hg1\\hg.70.jpg',
#  'D:/image\\dataset\\hg1\\hg.71.jpg',
#  'D:/image\\dataset\\hg1\\hg.72.jpg',
#  'D:/image\\dataset\\hg1\\hg.73.jpg',
#  'D:/image\\dataset\\hg1\\hg.74.jpg',
#  'D:/image\\dataset\\hg1\\hg.75.jpg',
#  'D:/image\\dataset\\hg1\\hg.76.jpg',
#  'D:/image\\dataset\\hg1\\hg.77.jpg',
#  'D:/image\\dataset\\hg1\\hg.79.jpg',
#  'D:/image\\dataset\\hg1\\hg.80.jpg',
#  'D:/image\\dataset\\hg1\\hg.82.jpg',
#  'D:/image\\dataset\\hg1\\hg.83.jpg',
#  'D:/image\\dataset\\hg1\\hg.93.png',
#  'D:/image\\dataset\\hg1\\hg.94 (2).png',
#  'D:/image\\dataset\\hg1\\hg.94 (3).png',
#  'D:/image\\dataset\\hg1\\hg.94.jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (1).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (1).png',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (29).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (29).png',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (37).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (4).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (40).png',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (44).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (47).png',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (48).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (49).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (49).png',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (50).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (52).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (52).png',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (57).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (58).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (59).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (61).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (63).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (63).png',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (66).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (68).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (7).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (71).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (74).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (75).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (76).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (79).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (84).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (87).jpg',
#  'D:/image\\dataset\\image_test1\\bhg\\bhg. (88).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (1).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (10).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (11).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (12).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (13).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (5).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (5).png',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (53).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (6).png',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (61).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (62).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (63).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (68).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (8).jpg',
#  'D:/image\\dataset\\image_test1\\hg\\hg. (9).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (1).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (1).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (10).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (10).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (11).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (12).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (13).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (13).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (14).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (14).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (15).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (15).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (16).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (16).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (17).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (17).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (18).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (18).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (19).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (19).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (2).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (2).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (20).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (20).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (21).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (21).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (22).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (22).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (23).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (23).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (24).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (24).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (25).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (25).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (26).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (26).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (27).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (27).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (28).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (28).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (29).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (29).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (3).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (3).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (30).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (30).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (31).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (31).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (32).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (32).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (33).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (33).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (34).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (34).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (35).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (35).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (36).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (36).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (37).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (37).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (38).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (38).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (39).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (39).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (4).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (4).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (40).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (40).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (41).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (41).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (42).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (42).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (43).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (43).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (44).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (44).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (45).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (45).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (46).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (46).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (47).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (47).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (48).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (48).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (49).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (49).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (5).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (5).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (50).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (50).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (51).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (51).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (52).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (52).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (53).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (53).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (54).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (54).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (55).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (55).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (56).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (56).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (57).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (57).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (58).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (58).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (59).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (59).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (6).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (6).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (60).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (60).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (61).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (61).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (62).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (63).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (64).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (65).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (7).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (7).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (8).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (8).png',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (9).jpg',
#  'D:/image\\dataset\\image_train\\bhg\\bhg. (9).png',
#  'D:/image\\dataset\\image_train\\hg\\hg.10.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.11.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.12.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.13.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.14.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.15.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.16.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.17.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.18.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.19.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.20.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.23.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.24.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.25.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.26.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.27.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.28.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.29.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.3.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.30.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.31.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.32.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.33.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.34.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.35.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.36.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.37.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.38.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.39.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.4.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.40.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.41.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.42.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.43.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.44.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.45.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.46.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.47.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.48.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.49.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.5.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.50.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.51.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.52.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.53.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.54.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.55.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.56.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.57.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.58.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.59.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.6.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.60.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.61.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.62.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.63.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.64.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.65.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.66.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.67.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.68.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.69.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.7.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.70.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.71.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.72.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.73.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.74.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.75.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.76.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.77.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.78.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.79.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.8.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.80.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.81.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.82.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.83.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.84.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.85.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.88.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.9.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.93.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.94.jpg',
#  'D:/image\\dataset\\image_train\\hg\\hg.95.png',
#  'D:/image\\dataset\\image_train\\hg\\hg.96.png',
#  'D:/image\\dataset\\web_image\\hg.10.png',
#  'D:/image\\dataset\\web_image\\hg.11.png',
#  'D:/image\\dataset\\web_image\\hg.12.png',
#  'D:/image\\dataset\\web_image\\hg.13.png',
#  'D:/image\\dataset\\web_image\\hg.14.png',
#  'D:/image\\dataset\\web_image\\hg.15.png',
#  'D:/image\\dataset\\web_image\\hg.16.png',
#  'D:/image\\dataset\\web_image\\hg.17.png',
#  'D:/image\\dataset\\web_image\\hg.18.png',
#  'D:/image\\dataset\\web_image\\hg.19.png',
#  'D:/image\\dataset\\web_image\\hg.20.png',
#  'D:/image\\dataset\\web_image\\hg.21.jpg',
#  'D:/image\\dataset\\web_image\\hg.22.jpg',
#  'D:/image\\dataset\\web_image\\hg.3.png',
#  'D:/image\\dataset\\web_image\\hg.4.png',
#  'D:/image\\dataset\\web_image\\hg.5.png',
#  'D:/image\\dataset\\web_image\\hg.6.png',
#  'D:/image\\dataset\\web_image\\hg.7.png',
#  'D:/image\\dataset\\web_image\\hg.78.png',
#  'D:/image\\dataset\\web_image\\hg.8.png',
#  'D:/image\\dataset\\web_image\\hg.81.png',
#  'D:/image\\dataset\\web_image\\hg.84.png',
#  'D:/image\\dataset\\web_image\\hg.85.png',
#  'D:/image\\dataset\\web_image\\hg.86.png',
#  'D:/image\\dataset\\web_image\\hg.87.png',
#  'D:/image\\dataset\\web_image\\hg.88.png',
#  'D:/image\\dataset\\web_image\\hg.89.png',
#  'D:/image\\dataset\\web_image\\hg.9.png',
#  'D:/image\\dataset\\web_image\\hg.90.png',
#  'D:/image\\dataset\\web_image\\hg.91.png',
#  'D:/image\\dataset\\web_image\\hg.92.png',
#  'D:/image\\dataset\\web_image\\hg.94 (1).png',
#  'D:/image\\dataset\\web_image\\hg.94 (10).png',
#  'D:/image\\dataset\\web_image\\hg.94 (11).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (12).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (13).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (14).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (15).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (16).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (17).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (18).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (19).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (20).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (21).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (22).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (24).jpg',
#  'D:/image\\dataset\\web_image\\hg.94 (3).png',
#  'D:/image\\dataset\\web_image\\hg.94 (4).png',
#  'D:/image\\dataset\\web_image\\hg.94 (5).png',
#  'D:/image\\dataset\\web_image\\hg.94 (6).png',
#  'D:/image\\dataset\\web_image\\hg.94 (7).png',
#  'D:/image\\dataset\\web_image\\hg.94 (8).png',
#  'D:/image\\dataset\\web_image\\hg.94 (9).png',
#  'D:/image\\dataset\\web_image\\hg.95.jpg',
#  'D:/image\\dataset\\web_image\\hg.96.jpg',
#  'D:/image\\dataset\\web_image\\hg.97.jpg',
#  'D:/image\\dataset\\web_image\\hg.jpg',
#  'D:/image\\tup\\bhg. (1).jpg',
#  'D:/image\\不合格\\bhg. (1).jpg',
#  'D:/image\\不合格\\bhg. (1).png',
#  'D:/image\\不合格\\bhg. (10).jpg',
#  'D:/image\\不合格\\bhg. (10).png',
#  'D:/image\\不合格\\bhg. (11).jpg',
#  'D:/image\\不合格\\bhg. (12).png',
#  'D:/image\\不合格\\bhg. (13).jpg',
#  'D:/image\\不合格\\bhg. (13).png',
#  'D:/image\\不合格\\bhg. (14).jpg',
#  'D:/image\\不合格\\bhg. (14).png',
#  'D:/image\\不合格\\bhg. (15).jpg',
#  'D:/image\\不合格\\bhg. (15).png',
#  'D:/image\\不合格\\bhg. (16).jpg',
#  'D:/image\\不合格\\bhg. (16).png',
#  'D:/image\\不合格\\bhg. (17).jpg',
#  'D:/image\\不合格\\bhg. (17).png',
#  'D:/image\\不合格\\bhg. (18).jpg',
#  'D:/image\\不合格\\bhg. (18).png',
#  'D:/image\\不合格\\bhg. (19).jpg',
#  'D:/image\\不合格\\bhg. (19).png',
#  'D:/image\\不合格\\bhg. (2).jpg',
#  'D:/image\\不合格\\bhg. (2).png',
#  'D:/image\\不合格\\bhg. (20).jpg',
#  'D:/image\\不合格\\bhg. (20).png',
#  'D:/image\\不合格\\bhg. (21).jpg',
#  'D:/image\\不合格\\bhg. (21).png',
#  'D:/image\\不合格\\bhg. (22).jpg',
#  'D:/image\\不合格\\bhg. (22).png',
#  'D:/image\\不合格\\bhg. (23).jpg',
#  'D:/image\\不合格\\bhg. (23).png',
#  'D:/image\\不合格\\bhg. (24).jpg',
#  'D:/image\\不合格\\bhg. (24).png',
#  'D:/image\\不合格\\bhg. (25).jpg',
#  'D:/image\\不合格\\bhg. (25).png',
#  'D:/image\\不合格\\bhg. (26).jpg',
#  'D:/image\\不合格\\bhg. (26).png',
#  'D:/image\\不合格\\bhg. (27).jpg',
#  'D:/image\\不合格\\bhg. (27).png',
#  'D:/image\\不合格\\bhg. (28).jpg',
#  'D:/image\\不合格\\bhg. (28).png',
#  'D:/image\\不合格\\bhg. (29).jpg',
#  'D:/image\\不合格\\bhg. (29).png',
#  'D:/image\\不合格\\bhg. (3).jpg',
#  'D:/image\\不合格\\bhg. (3).png',
#  'D:/image\\不合格\\bhg. (30).jpg',
#  'D:/image\\不合格\\bhg. (30).png',
#  'D:/image\\不合格\\bhg. (31).jpg',
#  'D:/image\\不合格\\bhg. (31).png',
#  'D:/image\\不合格\\bhg. (32).jpg',
#  'D:/image\\不合格\\bhg. (32).png',
#  'D:/image\\不合格\\bhg. (33).jpg',
#  'D:/image\\不合格\\bhg. (33).png',
#  'D:/image\\不合格\\bhg. (34).jpg',
#  'D:/image\\不合格\\bhg. (34).png',
#  'D:/image\\不合格\\bhg. (35).jpg',
#  'D:/image\\不合格\\bhg. (35).png',
#  'D:/image\\不合格\\bhg. (36).jpg',
#  'D:/image\\不合格\\bhg. (36).png',
#  'D:/image\\不合格\\bhg. (37).jpg',
#  'D:/image\\不合格\\bhg. (37).png',
#  'D:/image\\不合格\\bhg. (38).jpg',
#  'D:/image\\不合格\\bhg. (38).png',
#  'D:/image\\不合格\\bhg. (39).jpg',
#  'D:/image\\不合格\\bhg. (39).png',
#  'D:/image\\不合格\\bhg. (4).jpg',
#  'D:/image\\不合格\\bhg. (4).png',
#  'D:/image\\不合格\\bhg. (40).jpg',
#  'D:/image\\不合格\\bhg. (40).png',
#  'D:/image\\不合格\\bhg. (41).jpg',
#  'D:/image\\不合格\\bhg. (41).png',
#  'D:/image\\不合格\\bhg. (42).jpg',
#  'D:/image\\不合格\\bhg. (42).png',
#  'D:/image\\不合格\\bhg. (43).jpg',
#  'D:/image\\不合格\\bhg. (43).png',
#  'D:/image\\不合格\\bhg. (44).jpg',
#  'D:/image\\不合格\\bhg. (44).png',
#  'D:/image\\不合格\\bhg. (45).jpg',
#  'D:/image\\不合格\\bhg. (45).png',
#  'D:/image\\不合格\\bhg. (46).jpg',
#  'D:/image\\不合格\\bhg. (46).png',
#  'D:/image\\不合格\\bhg. (47).jpg',
#  'D:/image\\不合格\\bhg. (47).png',
#  'D:/image\\不合格\\bhg. (48).jpg',
#  'D:/image\\不合格\\bhg. (48).png',
#  'D:/image\\不合格\\bhg. (49).jpg',
#  'D:/image\\不合格\\bhg. (49).png',
#  'D:/image\\不合格\\bhg. (5).jpg',
#  'D:/image\\不合格\\bhg. (5).png',
#  'D:/image\\不合格\\bhg. (50).jpg',
#  'D:/image\\不合格\\bhg. (50).png',
#  'D:/image\\不合格\\bhg. (51).jpg',
#  'D:/image\\不合格\\bhg. (51).png',
#  'D:/image\\不合格\\bhg. (52).jpg',
#  'D:/image\\不合格\\bhg. (52).png',
#  'D:/image\\不合格\\bhg. (53).jpg',
#  'D:/image\\不合格\\bhg. (53).png',
#  'D:/image\\不合格\\bhg. (54).jpg',
#  'D:/image\\不合格\\bhg. (54).png',
#  'D:/image\\不合格\\bhg. (55).jpg',
#  'D:/image\\不合格\\bhg. (55).png',
#  'D:/image\\不合格\\bhg. (56).jpg',
#  'D:/image\\不合格\\bhg. (56).png',
#  'D:/image\\不合格\\bhg. (57).jpg',
#  'D:/image\\不合格\\bhg. (57).png',
#  'D:/image\\不合格\\bhg. (58).jpg',
#  'D:/image\\不合格\\bhg. (58).png',
#  'D:/image\\不合格\\bhg. (59).jpg',
#  'D:/image\\不合格\\bhg. (59).png',
#  'D:/image\\不合格\\bhg. (6).jpg',
#  'D:/image\\不合格\\bhg. (6).png',
#  'D:/image\\不合格\\bhg. (60).jpg',
#  'D:/image\\不合格\\bhg. (60).png',
#  'D:/image\\不合格\\bhg. (61).jpg',
#  'D:/image\\不合格\\bhg. (61).png',
#  'D:/image\\不合格\\bhg. (62).jpg',
#  'D:/image\\不合格\\bhg. (63).jpg',
#  'D:/image\\不合格\\bhg. (64).jpg',
#  'D:/image\\不合格\\bhg. (65).jpg',
#  'D:/image\\不合格\\bhg. (7).jpg',
#  'D:/image\\不合格\\bhg. (7).png',
#  'D:/image\\不合格\\bhg. (8).jpg',
#  'D:/image\\不合格\\bhg. (8).png',
#  'D:/image\\不合格\\bhg. (9).jpg',
#  'D:/image\\不合格\\bhg. (9).png',
#  'D:/image\\不合格图片\\信息不全\\60d3218be4b0d7b6fd1da32d.jpg',
#  'D:/image\\不合格图片\\信息不全\\60d32525e4b01497a1c7efa5.png',
#  'D:/image\\不合格图片\\信息不全\\60d3259ee4b0d7b6fd1da3a3.png',
#  'D:/image\\不合格图片\\信息不全\\60d328dbe4b01497a1c7f032.png',
#  'D:/image\\不合格图片\\信息不全\\60d3295ae4b0d7b6fd1da425.png',
#  'D:/image\\不合格图片\\信息不全\\60d32a7de4b0d2f1c6f47fc3.jpg',
#  'D:/image\\不合格图片\\信息不全\\60d32c05e4b0d2f1c6f47ff6.png',
#  'D:/image\\不合格图片\\信息不全\\60d32dc2e4b0d7b6fd1da4d3.jpg',
#  'D:/image\\不合格图片\\信息不全\\60d32fb5e4b00dd95190b352.png',
#  'D:/image\\不合格图片\\信息不全\\60d33070e4b00dd95190b381.jpg',
#  'D:/image\\不合格图片\\信息不全\\60d330b0e4b01497a1c7f16a.png',
#  'D:/image\\不合格图片\\信息不全\\60d331fce4b0d7b6fd1da578.png',
#  'D:/image\\不合格图片\\信息不全\\60d494c4e4b0d7b6fd1dbcd4.png',
#  'D:/image\\不合格图片\\模糊\\60d3276be4b0d2f1c6f47f3f.jpg',
#  'D:/image\\不合格图片\\模糊\\60d327fee4b01497a1c7f00e.png',
#  'D:/image\\不合格图片\\模糊\\60d32cd6e4b0d7b6fd1da4ac.jpg',
#  'D:/image\\不合格图片\\模糊\\60d32e14e4b0d7b6fd1da4e3.png',
#  'D:/image\\不合格图片\\模糊\\60d32fdae4b0d2f1c6f480b7.png',
#  'D:/image\\不合格图片\\模糊\\60d3309ae4b0d2f1c6f480e0.jpg',
#  'D:/image\\不合格图片\\模糊\\60d330cce4b0d2f1c6f480ec.png',
#  'D:/image\\不合格图片\\模糊\\60d33bcbe4b00dd95190b56b.jpg',
#  'D:/image\\不合格图片\\模糊\\60d34a94e4b01497a1c7f520.png',
#  'D:/image\\不合格图片\\模糊\\60d3ffe0e4b00dd95190bbfd.png',
#  'D:/image\\不合格图片\\模糊\\60d42846e4b01497a1c7ff85.png',
#  'D:/image\\不合格图片\\模糊\\60d433e1e4b0d7b6fd1db3d2.png',
#  'D:/image\\不合格图片\\模糊\\60d44d62e4b0d7b6fd1db71a.png',
#  'D:/image\\不合格图片\\模糊\\60d46277e4b01497a1c806c8.png',
#  'D:/image\\不合格图片\\模糊\\60d46f5be4b01497a1c80793.png',
#  'D:/image\\不合格图片\\模糊\\60d471e4e4b0d2f1c6f499b7.png',
#  'D:/image\\不合格图片\\模糊\\60d473f5e4b0d2f1c6f49a03.png',
#  'D:/image\\不合格图片\\模糊\\60d475dbe4b01497a1c8080b.png',
#  'D:/image\\不合格图片\\模糊\\60d47788e4b01497a1c80831.png',
#  'D:/image\\不合格图片\\模糊\\60d4807de4b0d7b6fd1dbacc.png',
#  'D:/image\\不合格图片\\模糊\\60d483c3e4b01497a1c80905.png',
#  'D:/image\\不合格图片\\模糊\\60d489bde4b01497a1c80991.png',
#  'D:/image\\不合格图片\\模糊\\60d48d02e4b01497a1c809dc.png',
#  'D:/image\\不合格图片\\模糊\\60d86dd7e4b0d2f1c6f4e3ac.jpg',
#  'D:/image\\不合格图片\\模糊\\60d88dece4b01497a1c84c5c.png',
#  'D:/image\\不合格图片\\模糊\\60d91d10e4b0d7b6fd1e1537.jpg',
#  'D:/image\\不合格图片\\模糊\\60d9401ae4b01497a1c858d1.jpg',
#  'D:/image\\不合格图片\\模糊\\60d97c97e4b00dd951912914.png',
#  'D:/image\\不合格图片\\模糊\\60d99aade4b00dd951913047.png',
#  'D:/image\\不合格图片\\模糊\\60d9a6d6e4b0d7b6fd1e3ac3.jpg',
#  'D:/image\\不合格图片\\模糊\\60d9b2e4e4b0d7b6fd1e4280.png',
#  'D:/image\\不合格图片\\模糊\\60da7058e4b01497a1c88253.jpg',
#  'D:/image\\不合格问题图片\\其他\\1-1.jpg',
#  'D:/image\\不合格问题图片\\其他\\1-2.jpg',
#  'D:/image\\不合格问题图片\\其他\\1-3.jpg',
#  'D:/image\\不合格问题图片\\其他\\1-4.jpg',
#  'D:/image\\不合格问题图片\\其他\\1-5.jpg',
#  'D:/image\\不合格问题图片\\其他\\1-6.jpg',
#  'D:/image\\不合格问题图片\\其他\\1.jpg',
#  'D:/image\\不合格问题图片\\图片信息不全\\1-2.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\1-3.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\1-4.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\1.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\2-1.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\3-1.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\3-2.jpg',
#  'D:/image\\不合格问题图片\\图片信息不全\\3-3.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\3-4.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\4-1.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\4-2.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\4-3.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\4-4.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\4-5.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\4-6.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\4-7.png',
#  'D:/image\\不合格问题图片\\图片信息不全\\5.png',
#  'D:/image\\不合格问题图片\\图片模糊\\1-2.png',
#  'D:/image\\不合格问题图片\\图片模糊\\1-3.png',
#  'D:/image\\不合格问题图片\\图片模糊\\1-4.png',
#  'D:/image\\不合格问题图片\\图片模糊\\1-5.png',
#  'D:/image\\不合格问题图片\\图片模糊\\1.png',
#  'D:/image\\不合格问题图片\\图片模糊\\2-1.png',
#  'D:/image\\不合格问题图片\\图片模糊\\2-2.png',
#  'D:/image\\不合格问题图片\\图片模糊\\2-3.png',
#  'D:/image\\不合格问题图片\\图片模糊\\2-4.png',
#  'D:/image\\不合格问题图片\\图片模糊\\2-5.png',
#  'D:/image\\不合格问题图片\\图片模糊\\2-6.png',
#  'D:/image\\不合格问题图片\\图片模糊\\2-7.png',
#  'D:/image\\不合格问题图片\\图片模糊\\2-8.png',
#  'D:/image\\不合格问题图片\\图片模糊\\3-1.png',
#  'D:/image\\不合格问题图片\\图片模糊\\3-2.png',
#  'D:/image\\不合格问题图片\\图片模糊\\3-3.png',
#  'D:/image\\不合格问题图片\\图片模糊\\3-4.png',
#  'D:/image\\不合格问题图片\\图片模糊\\4-1.png',
#  'D:/image\\不合格问题图片\\图片重复\\1-2.png',
#  'D:/image\\不合格问题图片\\图片重复\\1-3.png',
#  'D:/image\\不合格问题图片\\图片重复\\1-4.png',
#  'D:/image\\不合格问题图片\\图片重复\\1.png',
#  'D:/image\\不合格问题图片\\图片重复\\2-1.png',
#  'D:/image\\不合格问题图片\\图片重复\\2-2.png',
#  'D:/image\\不合格问题图片\\图片重复\\2-3.png',
#  'D:/image\\不合格问题图片\\图片重复\\3-1.png',
#  'D:/image\\不合格问题图片\\图片重复\\3-2.png',
#  'D:/image\\不合格问题图片\\图片重复\\3-3.png',
#  'D:/image\\不合格问题图片\\图片重复\\3-4.png',
#  'D:/image\\不合格问题图片\\图片重复\\4-1.png',
#  'D:/image\\不合格问题图片\\图片重复\\4-2.png',
#  'D:/image\\不合格问题图片\\图片重复\\4-3.png',
#  'D:/image\\不合格问题图片\\图片重复\\4-4.png',
#  'D:/image\\合格\\hg. (1).jpg',
#  'D:/image\\合格\\hg. (1).png',
#  'D:/image\\合格\\hg. (10).jpg',
#  'D:/image\\合格\\hg. (11).jpg',
#  'D:/image\\合格\\hg. (12).jpg',
#  'D:/image\\合格\\hg. (13).jpg',
#  'D:/image\\合格\\hg. (14).jpg',
#  'D:/image\\合格\\hg. (15).jpg',
#  'D:/image\\合格\\hg. (16).jpg',
#  'D:/image\\合格\\hg. (17).jpg',
#  'D:/image\\合格\\hg. (18).jpg',
#  'D:/image\\合格\\hg. (19).jpg',
#  'D:/image\\合格\\hg. (2).jpg',
#  'D:/image\\合格\\hg. (2).png',
#  'D:/image\\合格\\hg. (20).jpg',
#  'D:/image\\合格\\hg. (21).jpg',
#  'D:/image\\合格\\hg. (22).jpg',
#  'D:/image\\合格\\hg. (23).jpg',
#  'D:/image\\合格\\hg. (24).jpg',
#  'D:/image\\合格\\hg. (25).jpg',
#  'D:/image\\合格\\hg. (26).jpg',
#  'D:/image\\合格\\hg. (27).jpg',
#  'D:/image\\合格\\hg. (28).jpg',
#  'D:/image\\合格\\hg. (29).jpg',
#  'D:/image\\合格\\hg. (3).jpg',
#  'D:/image\\合格\\hg. (3).png',
#  'D:/image\\合格\\hg. (30).jpg',
#  'D:/image\\合格\\hg. (31).jpg',
#  'D:/image\\合格\\hg. (32).jpg',
#  'D:/image\\合格\\hg. (33).jpg',
#  'D:/image\\合格\\hg. (34).jpg',
#  'D:/image\\合格\\hg. (35).jpg',
#  'D:/image\\合格\\hg. (36).jpg',
#  'D:/image\\合格\\hg. (37).jpg',
#  'D:/image\\合格\\hg. (38).jpg',
#  'D:/image\\合格\\hg. (39).jpg',
#  'D:/image\\合格\\hg. (4).jpg',
#  'D:/image\\合格\\hg. (40).jpg',
#  'D:/image\\合格\\hg. (41).jpg',
#  'D:/image\\合格\\hg. (42).jpg',
#  'D:/image\\合格\\hg. (43).jpg',
#  'D:/image\\合格\\hg. (44).jpg',
#  'D:/image\\合格\\hg. (45).jpg',
#  'D:/image\\合格\\hg. (46).jpg',
#  'D:/image\\合格\\hg. (47).jpg',
#  'D:/image\\合格\\hg. (48).jpg',
#  'D:/image\\合格\\hg. (49).jpg',
#  'D:/image\\合格\\hg. (5).jpg',
#  'D:/image\\合格\\hg. (5).png',
#  'D:/image\\合格\\hg. (50).jpg',
#  'D:/image\\合格\\hg. (51).jpg',
#  'D:/image\\合格\\hg. (52).jpg',
#  'D:/image\\合格\\hg. (53).jpg',
#  'D:/image\\合格\\hg. (54).jpg',
#  'D:/image\\合格\\hg. (55).jpg',
#  'D:/image\\合格\\hg. (6).jpg',
#  'D:/image\\合格\\hg. (7).jpg',
#  'D:/image\\合格\\hg. (8).jpg',
#  'D:/image\\合格\\hg. (9).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625203974.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625203995(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625204035(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625204368(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625204396(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625204418(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625204446(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625204469(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625204493(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625204513(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625204850(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625205064(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625205086(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625205109(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625205151(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625205211(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625205224(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625208660(1).png',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625208689(1).png',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625208714(1).png',
#  'D:/image\\合格与不合格样本范例\\不合格样本-图片不全\\1625208750(1).png',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196518(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196569(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196593(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196618(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196641(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196662(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196677(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196695(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196734(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196762.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196793(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196811(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196824(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196841(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196865.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196903(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625196919(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197229(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197249(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197265(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197287.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197303(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197322(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197431(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197484(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197539(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197838(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197857(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625197870(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625208532(1).png',
#  'D:/image\\合格与不合格样本范例\\不合格样本-模糊图片\\1625208898(1).png',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198086(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198101(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198113(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198134(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198148(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198169(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198181(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198196(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198211(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198229(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198244(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198255(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198269(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198517(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198530(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198544(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198557(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198571(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198596(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198633(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198684(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198791(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198801(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198816(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198835(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198849(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625198866(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625199143(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625199156(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625199172(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625199186(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625199204(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625199218(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625199262(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625199274(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\1625199288.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\重复类型1.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\重复类型2.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\重复类型3.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\重复类型4.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\重复类型5.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本-重复图片\\重复类型6.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625205703(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625205718(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625205883(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625205903(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625205918.jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625205939(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625205951(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625205992(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625206006(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625206032(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625206064(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625206080(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625206104(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625206118(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625206273(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625206298(1).jpg',
#  'D:/image\\合格与不合格样本范例\\不合格样本—其他原因\\1625206331(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207533(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207551(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207567(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207583(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207602(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207616(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207634(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207652(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207684(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207701(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207724(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207739(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207753(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207767(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207802(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207833.jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207854(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207912(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207932(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625207984(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208009(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208023(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208037(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208107(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208122(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208139(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208162(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208220(1).jpg',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208806(1).png',
#  'D:/image\\合格与不合格样本范例\\合格样本\\1625208830(1).png',
#  'D:/image\\问题图片收集\\图片信息不全\\60c09dc2e4b0d7b6fd1c2d0e.jpg',
#  'D:/image\\问题图片收集\\图片信息不全\\60c09ec1e4b0d2f1c6f2ea8d.jpg',
#  'D:/image\\问题图片收集\\图片信息不全\\60d1f90de4b00dd951909569.png',
#  'D:/image\\问题图片收集\\图片信息不全\\60d26522e4b00dd9519099a8.jpg',
#  'D:/image\\问题图片收集\\图片信息不全\\60d2d144e4b0d7b6fd1d9a4a.png',
#  'D:/image\\问题图片收集\\图片信息不全\\【2】运营医生名单.xlsx.png',
#  'D:/image\\问题图片收集\\图片模糊\\60d1f9b3e4b0d2f1c6f4628b.jpg',
#  'D:/image\\问题图片收集\\图片模糊\\60d206eee4b00dd95190975d.png',
#  'D:/image\\问题图片收集\\图片模糊\\60d27048e4b0d2f1c6f4677b.jpg',
#  'D:/image\\问题图片收集\\图片重复\\1\\60c0137ae4b00dd9518f1bcb.png',
#  'D:/image\\问题图片收集\\图片重复\\1\\60c013b5e4b0d7b6fd1c1fba.png',
#  'D:/image\\问题图片收集\\图片重复\\2\\60d1fa46e4b0d7b6fd1d89bc.jpg',
#  'D:/image\\问题图片收集\\图片重复\\2\\60d1fa4ae4b0d7b6fd1d89bd.jpg',
#  'D:/image\\问题图片收集\\图片重复\\3\\60d1fb56e4b01497a1c7d1ba.jpg',
#  'D:/image\\问题图片收集\\图片重复\\3\\60d1fb76e4b01497a1c7d1bf.jpg',
#  'D:/image\\问题图片收集\\来源网络\\60bcc5bee4b0d2f1c6f29d1c.jpg',
#  'D:/image\\问题图片收集\\来源网络\\60bd9096e4b0d7b6fd1beea9.jpg',
#  'D:/image\\问题图片收集\\来源网络\\60bdffc8e4b00dd9518ef98e.jpg',
#  'D:/image\\问题图片收集\\来源网络\\60cef950e4b0d2f1c6f3dea4.jpg',
#  'D:/image\\问题图片收集\\来源网络\\60d1fb76e4b01497a1c7d1bf.jpg']

# %%
import os
from openpyxl import Workbook

path = "D:/image/"
file_name = os.listdir(path)
item_list =[]
 
for item in file_name:
    if item[-4:].lower() == '.jpg' or item[-4:].lower() == '.png' or item[-5:].lower() == '.jpeg':
        item = path + item
        item_list.append(item)
        
item_list =[]

# %%
list_set = []
for i in range(len(item_list)):
    for j in range(i+1,len(item_list)):
        list = [item_list[i],item_list[j]]
        list_set.append(list)    
list_set
# Out:
# []

# %%
b = []
if __name__ == "__main__":
    list_set = []
    for i in range(len(item_list)):
        for j in range(i+1,len(item_list)):
            list = [item_list[i],item_list[j]]
            list_set.append(list) 
    for i in range(len(list_set)):
        p1= item_list[i][0]
        p2= item_list[i][1]
        a = runAllImageSimilaryFun(p1,p2)
